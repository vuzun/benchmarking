# %%
a_normal_one <- rnorm(10,2,0.5)
print(a_normal_onermal_one)
# Out:
#  [1] 1.759885 2.721167 1.335702 2.298105 1.678237 1.485924 2.319832 2.473665
#  [9] 1.858496 2.559572

# %%
hist(a_normal_one)
# Out:
# Plot with title "Histogram of a_normal_one"

# %%
mean(a_normal_one)
# Out:
# [1] 2.049059

# %%
sd(a_normal_one)
# Out:
# [1] 0.4843586
